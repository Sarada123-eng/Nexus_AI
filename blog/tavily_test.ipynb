# %%
from langchain_community.tools.tavily_search import TavilySearchResults
from dotenv import load_dotenv
load_dotenv()  # Load environment variables from .env file
# Out:
# True
# d:\Python_Practice\LangGraph\venv\lib\site-packages\google\api_core\_python_version_support.py:273: FutureWarning: You are using a Python version (3.10.6) which Google will stop supporting in new releases of google.api_core once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.api_core past that date.
#   warnings.warn(message, FutureWarning)

# %%
tool = TavilySearchResults(max_results=3)
results = tool.invoke("ChatGPT version releases and updates from 2022 to 2026")
print(results)
# Out:
# C:\Users\sarad\AppData\Local\Temp\ipykernel_5632\1173406996.py:1: LangChainDeprecationWarning: The class `TavilySearchResults` was deprecated in LangChain 0.3.25 and will be removed in 1.0. An updated version of the class exists in the `langchain-tavily package and should be used instead. To use it run `pip install -U `langchain-tavily` and import as `from `langchain_tavily import TavilySearch``.
#   tool = TavilySearchResults(max_results=3)
# [{'title': 'OpenAI GPT & ChatGPT Timeline (2022 → Feb 2026) - LinkedIn', 'url': 'https://www.linkedin.com/pulse/openai-gpt-chatgpt-timeline-2022-feb-2026-sanjana-r-pmp-cspo--pxfoc', 'content': '### GPT-4o — May 2024\n\n Introduced as a faster, cheaper, fully multimodal model\n Supported text, vision, and later real-time voice\n Positioned as the default GPT-4–level experience in ChatGPT\n Emphasized reduced latency and more natural interaction\n\n### GPT-4.1 — April–May 2025\n\n Released in the API in April 2025\n Rolled out to paid ChatGPT users on May 14, 2025\n Framed as a higher-precision, coding-optimized successor to GPT-4o\n Improved instruction following and structured outputs\n\n### GPT-4o / 4.1 Mini Lifecycle and Retirement\n\n### GPT-4.1 Mini & 4o Mini — May 2025\n\n GPT-4.1 mini launched on May 14, 2025\n Explicitly replaced GPT-4o mini in the ChatGPT model picker\n Served as the fallback model for free users once GPT-4o usage limits were reached [...] ### ChatGPT (GPT-3.5) — November 2022\n\n Public launch as a research preview in late November 2022\n Built on the GPT-3.5 family (often referred to as GPT-3.5 Turbo in API documentation)\n Marked the first large-scale, consumer-facing conversational interface for GPT models\n\n### GPT-4 — March 2023\n\n Officially announced by OpenAI in March 2023\n Described as a larger, more capable multimodal model\n Initially released via the API, followed shortly by availability in ChatGPT Plus\n Focused on improved reasoning, instruction following, and reliability\n\n### GPT-4o — May 2024 [...] ### GPT-5 in ChatGPT — August 12, 2025\n\n GPT-5 appeared in ChatGPT with an Auto / Fast / Thinking selector\n Introduced higher Plus usage limits\n GPT-5 Thinking was documented with a 196k token context window\n Positioned as the default intelligence layer rather than a single fixed model\n\n### Thinking-Time Toggle — September 17, 2025\n\n ChatGPT added a thinking-time control in the composer for GPT-5\n Allowed users (Plus, Business, Pro) to select different reasoning depths\n Exposed reasoning time as a user-controlled parameter, rather than an internal system choice\n\n### GPT-5.2 & Reasoning Tiers — Late 2025 → Early 2026', 'score': 0.9322132}, {'title': 'ChatGPT Version History – Features and Updates - Objects', 'url': 'https://objects.ws/blog/chatgpt-version-history', 'content': 'ChatGPT VersionsRelease DateCrucial Features\nChatGPT 5.5 April 2026 The latest version prioritizes reasoning, agentic coding, deep research, and computer use (autonomous navigation of interfaces).\nChatGPT 5.4 March 2026 This version valued reasoning, agentic workflows, and coding. Users were able to perform crucial tasks, such as deep web search. Moreover, it helped maintain context more effectively for queries that usually required detailed thinking.\nChatGPT 5.3 GPT-5.3-Codex was launched in February 2026. GPT-5.3 Instant was introduced in March 2026.This version was handy for enhancing full-cycle software development along with collaboration. It also delighted users through more accurate, logical answers. [...] ChatGPT 5.2 December 2025 The version, GPT-5.2, favored routine activities and learning. Users were allowed to ask technical questions in a conversational tone.\nChatGPT 5.1 November 2025 Answers have become smarter and conversational. GPT-5.1 Instant and GPT 5.1 Thinking were launched to provide users with more simplified and precise responses.\nChatGPT 5August 2025 GPT-5 demonstrated tool coordination, context management, and improved reasoning.\nChatGPT Agent July 2025 ChatGPT Agent helped users manage their tasks. It worked as a combination of Operator, Codex, and Deep Research.\nOpenAI o3 and o4-mini Launch April 2025 These models provided enhanced reasoning capabilities. [...] ## What is GPT-5.2?\n\nGPT-5.2 officially came to market on December 11, 2025. This version supported beginners, experienced professionals, and other users. GPT-5.2 Instant, the advanced model, was beneficial fo ...
